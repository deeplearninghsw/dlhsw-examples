# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from utils.plotting import plot_kmeans_boundaries

from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('data/ex.csv')

dataset = df.copy()

X = dataset.values
x_cords = dataset['x'].values
y_cords = dataset['y'].values

# %%
kmeans = KMeans(n_clusters=3, max_iter=3_000)
kmeans.fit(X)
y_pred = kmeans.predict(X)

plot_kmeans_boundaries(X, y_cords, y_pred, kmeans.cluster_centers_, kmeans, 'KMeans Clustering')

score = kmeans.score(X, y_cords)
print(f"Score: {score}")
# Out:
# Score: -912.0491458084546
